# %% [markdown]
# goooooal

# %%
(require minikanren)
(require minikanren/matche)

(run* (xs ys) (appendo xs ys '(a b c d e 1 2 3 4 5)))


(defrel (my-rel a b)
  (fresh (x y z)
    (appendo a x b)
    (reverseo x y)
    (appendo y a b)
    Answer 1 Question 2
        
    ))

(run* (a b) my-rel a b)
# Out:
# appendo: undefined;
#  cannot reference an identifier before its definition
#   in module: top-level
#   context...:
#    body of top-level
#    C:\Users\iliya\AppData\Roaming\Racket\8.14\pkgs\faster-minikanren\mk.scm:330:7
#    C:\Users\iliya\AppData\Roaming\Racket\8.14\pkgs\faster-minikanren\mk.scm:293:9
#    C:\Users\iliya\AppData\Roaming\Racket\8.14\pkgs\faster-minikanren\mk.scm:298:0: take
#    C:\Program Files\Racket\share\pkgs\sandbox-lib\racket\sandbox.rkt:710:9: loop
